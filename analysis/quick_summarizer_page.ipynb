# %% [markdown]
# # Quick page-wise summarizer
#
# Summarizer
# Goal: Summarize a long-form RFP
#
#     Page-wise summaries
#         Input
#             RFP, broken into pages
#             Summary prompt
#         Output
#             Short summary, per page
#     Consolidator
#         Input
#             Per page summary
#             Consolidation prompt
#         Output
#             Consolidated summary

# %%
# %load_ext autoreload
# %autoreload 1

# %%
import sys
sys.path.append('../rfpgo/')
from credentials import *
from process.prompts import *
from utils import *
import os
import pandas as pd
from pathlib import Path
import PyPDF2
os.environ["OPENAI_API_KEY"] = OPENAI_KEY
os.environ["ANTHROPIC_API_KEY"] = ANTHROPIC_KEY

# %%
from langchain.llms import Ollama
from langchain_openai import OpenAI, ChatOpenAI
from langchain_anthropic import ChatAnthropic
# trying gemma 2
gemma = Ollama(model="gemma2")
oai_3 = ChatOpenAI(model='gpt-3.5-turbo')
oai_4 = ChatOpenAI(model='gpt-4-turbo')
oai_4o = ChatOpenAI(model='gpt-4o')
oai_4omini = ChatOpenAI(model='gpt-4o-mini')
anth_haiku = ChatAnthropic(model='claude-3-haiku-20240307')
anth_opus = ChatAnthropic(model='claude-3-opus-20240229')
# Out:
# /var/folders/zy/m11fhccd7mb2gppqt47pstgh0000gp/T/ipykernel_2263/3680499657.py:5: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   gemma = Ollama(model="gemma2")

# %% [markdown]
# ## Summarizer
# This is a different sort of summarizer than the quick one - the idea is to summarize page by page and then consolidate those into a single summary

# %%
class Summarizer(object):
    page_prompt = page_summary
    consolidate_prompt_long = consolidate_summary_long
    consolidate_prompt_short = consolidate_summary_short

    def __init__(self, llm, fn):
        self.llm = llm
        self.llm_name = llm.dict()['model']
        self.split_doc = self._splitter(fn)

    def _splitter(self, doc):
        # Open the PDF file
        pdf_file = open(fn, 'rb')

        # Create a PDF reader object
        pdf_reader = PyPDF2.PdfReader(pdf_file)

        # Loop through each page and extract the text
        collect = []
        for p in pdf_reader.pages:
            text = p.extract_text()
            collect.append(text)
        return collect 
    
    def summarize(self):
        # pagewise summaries
        self.page_summaries = []
        for s in self.split_doc:
            p = self.page_prompt.format(document=s)
            self.page_summaries.append(call_llm(p, self.llm))

        # consolidate
        joined_p = ''
        for i, p in enumerate(self.page_summaries):
            joined_p += f'Page {i+1}: {p}\n\n'
        c = self.consolidate_prompt_long.format(document=joined_p)
        self.summary = call_llm(c, self.llm)

        # short summary
        c = self.consolidate_prompt_short.format(document=self.summary)
        self.summary_short = call_llm(c, self.llm)

# %%
# example rfp
fn = '../data/labels/drafter_09262024/RFP_Study to evaluate methods to calculate area median income.pdf'

# %%
summary_dict = {}

for model in [gemma, oai_3, oai_4]:
    model_name = model.dict()['model']
    if model_name not in summary_dict:
        summary_dict[model_name] = Summarizer(model, fn)
        summary_dict[model_name].summarize()

    # output to csv
    result = pd.DataFrame.from_records(zip(
        summary_dict[model_name].split_doc, 
        summary_dict[model_name].page_summaries),
        columns=['document', 'summary'])
    result.loc[0, 'long_summary'] = summary_dict[model_name].summary
    result.loc[0, 'short_summary'] = summary_dict[model_name].summary_short
    result.to_csv(f'../data/output/drafter_09262024/summaries_{model_name}.csv', index=False)
# Out:
# /var/folders/_k/42sqpt052kz96fmjll5__xxw0000gn/T/ipykernel_65609/1614567369.py:14: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'The provided text appears to be excerpts from a contract between the Washington Department of Commerce (COMMERCE) and a contractor. It outlines various terms and conditions, covering financial aspects, insurance requirements, legal obligations, dispute resolution, and administrative details.
#
# **Key Highlights:**
#
# * **Financial Terms:**
#     * Detailed breakdown of compensation limits, expense reimbursement procedures, billing requirements, and payment timelines on Page 33.
#     * Specific invoicing requirements, prohibited duplicate billing practices, and responsibility for disallowed costs outlined on Page 34.
#     * Mandatory use of the Access Equity platform for subcontractor data collection and reporting.
# * **Insurance Requirements:**
#     * Specific types and minimum coverage amounts required for liability, cyber liability, automobile liability, professional errors and omissions, and fidelity insurance on Pages 35 & 36.
# * **Legal and Ethical Obligations:**
#     * Compliance with the Americans with Disabilities Act (ADA), restrictions on contract assignment, attorney fees provisions, confidentiality obligations, safeguarding personal information, and addressing potential conflicts of interest on Page 38.
#     * Rules regarding conflicts of interest, copyright ownership, and dispute resolution procedures on Page 39.
#
# * **Dispute Resolution & Governing Law:**
#     * Dispute resolution process, prohibition against duplicate payment, Washington law governing the contract, venue in Thurston County Superior Court, indemnification obligations, independent contractor status clarification, and industrial insurance coverage compliance outlined on Page 40.
# * **General Contractual Provisions:**
#     * Labor laws compliance, licensing regulations, non-discrimination policies, limitations on contract modification, consequences for non-compliance on Page 41.
#
# * **Grantee Obligations & Administrative Details:**
#     * Financial accountability, pay equity, limitations on political activities, publicity usage, and consequences for non-compliance outlined for the grantee on Page 42.
#     * Record-keeping requirements, inspection rights, subcontracting procedures, funding contingencies, severability clauses, site security protocols, and subcontractor compliance on Page 43.
#
#
# **Overall:** The text provides a comprehensive overview of the contractual terms and conditions governing the relationship between COMMERCE and its contractor. It emphasizes financial transparency, legal compliance, ethical conduct, and clear communication throughout the project lifecycle.
#
#
#
# Let me know if you have any further questions or need additional clarification on specific sections!' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result.loc[0, 'long_summary'] = summary_dict[model_name].summary
# /var/folders/_k/42sqpt052kz96fmjll5__xxw0000gn/T/ipykernel_65609/1614567369.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Here's a shortened summary focused on drafting a proposal response:
#
# **COMMERCE RFP Key Points for Proposal:**
#
# * **Financials:**  Detailed compensation limits, expense reimbursement, billing procedures, and payment timelines are outlined. Understand the mandatory Access Equity platform for subcontractor data.
# * **Insurance:** Specific coverage amounts and types are required (liability, cyber liability, auto, professional errors & omissions, fidelity). Proof of insurance will be needed.
# * **Legal & Ethical:** Ensure your response addresses ADA compliance, non-assignment of contract, confidentiality obligations, safeguarding personal information, and potential conflicts of interest.
# * **Dispute Resolution:**  Familiarize yourself with the dispute resolution process outlined. Washington law governs the contract, and Thurston County Superior Court is the designated venue.
#
# **Additional Considerations:**
#
# * Subcontractor management: Understand the requirements for using subcontractors and reporting their data through Access Equity.
# * Labor laws & licensing: Confirm compliance with applicable labor laws and licensing regulations.
# * Non-discrimination:  Clearly state your commitment to non-discrimination policies.
# * Publicity & Use of Logo: Be aware of restrictions on publicizing the contract and using COMMERCE's logo.
#
#
# **Remember:** Carefully review all pages referenced in the summary to ensure a complete understanding of the RFP requirements before drafting your proposal.
# ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result.loc[0, 'short_summary'] = summary_dict[model_name].summary_short
# /var/folders/_k/42sqpt052kz96fmjll5__xxw0000gn/T/ipykernel_65609/1614567369.py:14: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'The State of Washington Department of Commerce is soliciting proposals for a study to evaluate current and alternative methods for calculating Area Median Income (AMI) in the state. Proposals are due by August 20, 2024, with an estimated contract period from September 19, 2024, to June 30, 2025, and payments made on a reimbursement basis. The study aims to identify alternative AMI calculation methods, engage stakeholders, conduct a literature review, and provide recommendations to the legislature by June 30, 2025. The contractor will compare current and alternative methods, analyze impacts, feasibility, and stakeholder feedback, and provide recommendations for the best method to calculate AMI in Washington. The final report is due by April 28, 2025, with additional requirements for an editable PowerPoint, video presentation, live presentations, compliance with accessibility requirements, and specific formatting guidelines. Proposers must meet minimum qualifications, including being licensed in Washington, and the budget for the project should not exceed $225,000. The RFP outlines the procurement process, submission requirements, evaluation criteria, protest procedures, and contracting information. Additionally, the document includes details on contract management, insurance requirements, subcontracting, termination, dispute resolution, compliance with laws and regulations, and other general terms and conditions. Small and Veteran-Owned Business certification is required, and failure to comply with requirements may result in disqualification or termination of the contract.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result.loc[0, 'long_summary'] = summary_dict[model_name].summary
# /var/folders/_k/42sqpt052kz96fmjll5__xxw0000gn/T/ipykernel_65609/1614567369.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'The State of Washington Department of Commerce is seeking proposals for a study to evaluate current and alternative methods for calculating Area Median Income (AMI). Proposals are due by August 20, 2024, with a contract period from September 19, 2024, to June 30, 2025. The study aims to identify alternative calculation methods, engage stakeholders, conduct a literature review, and provide recommendations by June 30, 2025. Contractors must compare current and alternative methods, analyze impacts, feasibility, and stakeholder feedback, and provide recommendations. The final report is due by April 28, 2025, with additional requirements for presentation formats and compliance. Proposers must be licensed in Washington and the budget should not exceed $225,000. The RFP outlines submission requirements, evaluation criteria, protest procedures, contracting information, and other general terms and conditions. Certification as a Small and Veteran-Owned Business is required.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result.loc[0, 'short_summary'] = summary_dict[model_name].summary_short
# /var/folders/_k/42sqpt052kz96fmjll5__xxw0000gn/T/ipykernel_65609/1614567369.py:14: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'The State of Washington Department of Commerce has issued a Request for Proposals (RFP) seeking qualified proposers to conduct a comprehensive study on the calculation methods of Area Median Income (AMI) in Washington State. This study, mandated by the 2024 supplemental budget, involves evaluating current AMI calculation methods against alternative models to potentially recommend more accurate or suitable methodologies. The project will run from September 19, 2024, to June 30, 2025, with a budget cap of $225,000.
#
# Proposals are due by August 20, 2024, and must be submitted electronically. The RFP process includes a pre-proposal conference scheduled for July 31, 2024, and various stages of proposal evaluation, including a possible interview or presentation by top-scoring proposers. The successful contractor will engage in tasks such as data collection, stakeholder engagement, and a thorough analysis of the impact of different AMI calculation methods. Deliverables will include draft and final reports, a PowerPoint, and a video presentation, all adhering to accessibility and plain language guidelines.
#
# Key requirements for proposers include adherence to a Diverse Business Inclusion Plan, with preference given to small or veteran-owned businesses for contracts under $150,000. Proposals must demonstrate the proposer’s qualifications, experience, and previous work related to housing programs and data analysis. Furthermore, the successful contractor will need to comply with various insurance requirements, manage subcontracting responsibly, and ensure all contractual activities align with state laws and guidelines provided by COMMERCE.
#
# The contractor will produce a final report with recommendations on AMI calculation methods by June 30, 2025. These recommendations will be informed by a comprehensive review of existing methods, stakeholder feedback, and an analysis of potential impacts on housing affordability and program eligibility in Washington. The project aims to offer well-researched suggestions to the legislature that could lead to more equitable housing policies.
#
# Kayla Judd is designated as the RFP Coordinator and the sole point of contact for all official communications regarding the RFP. Any disputes or protests arising from the RFP process are to be managed according to specified procedures, ensuring fairness and compliance throughout the contracting process. The document also outlines detailed contract management terms, including payment schedules, insurance obligations, and compliance with nondiscrimination policies, providing a structured and transparent framework for the execution of the contract.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result.loc[0, 'long_summary'] = summary_dict[model_name].summary
# /var/folders/_k/42sqpt052kz96fmjll5__xxw0000gn/T/ipykernel_65609/1614567369.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'The State of Washington Department of Commerce is requesting proposals for a study on Area Median Income (AMI) calculation methods. This study, required by the 2024 supplemental budget, will assess current methods and explore alternatives to improve accuracy and suitability. The project period is from September 19, 2024, to June 30, 2025, with a budget limit of $225,000.
#
# Proposals must be submitted electronically by August 20, 2024. The selection process includes a pre-proposal conference on July 31, 2024, followed by evaluations and possibly interviews or presentations. Key tasks for the chosen contractor include data collection, stakeholder engagement, and analysis, with deliverables such as reports, a PowerPoint, and a video presentation—all adhering to accessibility standards.
#
# Proposers are expected to demonstrate expertise in housing programs and data analysis, comply with insurance and subcontracting requirements, and follow state laws and guidelines. Preference is given to small or veteran-owned businesses for contracts under $150,000. The final outcome will be a report with recommendations on AMI calculation methods by June 30, 2025, aimed at informing potential policy changes for equitable housing.
#
# Kayla Judd is the RFP Coordinator, serving as the main contact for all related communications. Disputes or protests will be handled according to outlined procedures, ensuring a fair and compliant contracting process.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result.loc[0, 'short_summary'] = summary_dict[model_name].summary_short

# %%
# display results
print(gemma_summary.summary_short)
print('--')
print(gemma_summary.summary)
# Out:
# ##  Washington Department of Commerce Contract Template Summary (For Bid Response)
#
# **Focus:** This template outlines the legal framework for working with the Washington Department of Commerce (COMMERCE). **Your response must address ALL its provisions.**
#
# **Key Areas to Address:**
#
# * **Basic Information:** Clearly state your company details, contract amount, funding source, project dates, and purpose.
# * **Special Terms & Conditions:**  Detail your compensation structure, expense policies, billing procedures, and payment timeline. Demonstrate understanding of COMMERCE's right to terminate or withhold payments.
# * **Financial Management:**
#     * Outline your billing procedures and ensure compliance with cost limitations.
#     * Clearly state how you will report subcontractor information through the Access Equity platform.
#     * Provide evidence of all required insurance coverage (general liability, cyber liability, automobile liability, professional liability, and fidelity).
# * **Legal & Ethical Considerations:** Address ADA compliance, conflict of interest protocols, confidentiality agreements, and acceptance of gratuities. Clarify copyright ownership procedures.
# * **Dispute Resolution & Contract Enforcement:**  Demonstrate understanding of dispute resolution procedures and payment terms. Clearly state your agreement to the governing law.
#
# * **Contract Administration & Performance:**
#     * Detail your recordkeeping processes, compliance with audits, and subcontracting procedures.
#     * Address security policies and contingencies like funding changes.
#     * Outline your plan for contract termination, including asset handling.
#
# **Attachments:**  Meticulously complete Attachment A (Scope of Work) to demonstrate precise understanding of project requirements. Develop a comprehensive Attachment B (Budget) that aligns with the specified scope.
#
#
#
#  **Remember:** This template is designed to protect COMMERCE. Your bid response must demonstrate thorough comprehension and meticulous compliance with all its provisions.
#
# --
# This document appears to be a standard contract template used by the Washington Department of Commerce (COMMERCE). It covers a wide range of topics essential for a legally binding agreement between COMMERCE and a contractor.
#
# Here's a breakdown based on the provided pages:
#
# **Key Contract Elements:**
#
# * **Basic Information (Page 32):**  Outlines fundamental details like contract amount, funding source, dates, contact information, and purpose.
# * **Special Terms & Conditions (Page 33):**  Covers compensation, expenses, billing, payment timelines, and consequences for non-performance. Emphasizes COMMERCE's right to terminate or withhold payments.
# * **Financial Management (Pages 34-38):**
#     * Billing procedures, cost limitations, subcontractor reporting requirements using the Access Equity platform (Page 34).
#     * Insurance requirements for general liability, cyber liability, automobile liability, professional liability, and fidelity insurance (Pages 35-36).
#     * Contractual obligations regarding compliance with laws, licenses, non-discrimination policies, and limitations on modifications (Page 41).
# * **Legal & Ethical Considerations (Pages 38-39):**
#     * Compliance with the Americans with Disabilities Act (ADA), restrictions on contract assignment, provisions for attorneys' fees, confidentiality, and conflict of interest.  Prohibitions against conflicts of interest and acceptance of gratuities, along with copyright ownership procedures (Page 39).
# * **Dispute Resolution & Contract Enforcement (Pages 40-42):**
#     * Procedures for resolving disputes, payment terms, governing law, indemnification obligations, and the Contractor's independent contractor status (Page 40).
#     *  Legal requirements and restrictions for contractors, including compliance with laws, licensing, discrimination prohibitions, and limitations on contractual modifications. Emphasizes adherence to non-discrimination policies and cooperation with investigations (Page 41).
#
# * **Contract Administration & Performance (Pages 43-46):**
#     * Administrative and financial obligations of the Contractor, including recordkeeping requirements, access for audits, subcontracting procedures, adherence to security policies, contingencies like funding changes, and enforceability provisions (Page 43).
#     * Provisions related to subcontractors, survival of contract terms, taxes, termination for cause or convenience, and payment terms upon termination (Page 44).
#     * Procedures for contract termination by COMMERCE, Contractor's obligations upon notice, and handling of assets (Pages 45-46).
#
# * **Attachment A: Scope of Work:**  Provides detailed information about the specific work to be performed by the contractor under the agreement.
# * **Attachment B: Budget:** Outlines a detailed financial breakdown for the project or initiative.
#
#
# **Overall:** This contract template aims to ensure clarity, fairness, and legal compliance in the relationship between COMMERCE and its contractors. It covers a comprehensive range of aspects from financial management and insurance requirements to legal obligations and dispute resolution.
#
#
#
# Let me know if you need further clarification on any specific sections or have any other questions.
